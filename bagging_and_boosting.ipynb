# %% [markdown]
# <a href="https://colab.research.google.com/github/shama12hegde/4NI22CI052_ML_2/blob/main/bagging_and_boosting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program: Bagging Classification on a Supervised Dataset
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load supervised dataset
data = load_iris()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Base model
base_model = DecisionTreeClassifier()

# Bagging ensemble
bag_model = BaggingClassifier(
    estimator=base_model,
    n_estimators=20,
    random_state=42
)

# Train
bag_model.fit(X_train, y_train)

# Predict
y_pred = bag_model.predict(X_test)

# Performance
acc = accuracy_score(y_test, y_pred)
print("Bagging Accuracy:", acc)
# Out:
# Bagging Accuracy: 1.0

# %%
# Program: AdaBoost Classification on a Supervised Dataset
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_iris()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Weak learner
weak_learner = DecisionTreeClassifier(max_depth=1)

# AdaBoost model
ada_model = AdaBoostClassifier(
    estimator=weak_learner,
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# Train
ada_model.fit(X_train, y_train)

# Predict
y_pred = ada_model.predict(X_test)

# Performance
acc = accuracy_score(y_test, y_pred)
print("Boosting (AdaBoost) Accuracy:", acc)
# Out:
# Boosting (AdaBoost) Accuracy: 1.0
